# %% [markdown]
# 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# https://www.kaggle.com/c/plant-seedlings-classification
# Plant Seedlings Classification(植物幼苗分類)
# Determine the species of a seedling from an image(植物幼苗分類)
# 1. 你選的這組資料為何重要
#
#     Answer:  分出雜草與作物幼苗是很重要的一件事，可以有效的幫忙新手農夫分類管理作物
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#      Answer:  資料提供者:Aarhus University Department of Engineering Signal Processing Group for hosting the original data.
#            方式蒐集
# 3. 蒐集而來的資料型態為何
#
#     Answer: 大量的實際圖片，植物名稱資料
#
# 4. 這組資料想解決的問題如何評估
#
#    Answer:分析比對
#
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     Answer:  地區與時段(如火車到站時間) 提升業績是否有相關
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#      Answer: 1. 都市與鄉村, 人們習慣, 治安條件...等，可能對地區與時段提升業績產生影響
#                     2.資料如何蒐集:戴客記錄,問卷調查,火車時刻表.....
#
# 3. 蒐集而來的資料型態為何
#
#      Answer: 時間,距離,地點
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#      Answer:預設某地區某個時段的戴客量,與實際資料相比對
#
#
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(yr,yp):
    """
    Args:
        - yr: 預測值
        - yp: 實際值
    Return:MSE
    """
    MSE  = sum(abs(yr - yp)**2) / len(yp)

    return MSE 

def mean_absolute_error(yr,yp):
    """
    Args:
        - yr: 預測值
        - yp: 實際值
    Return:MSE
    """
    MAE =  sum(abs(yr - yp)) / len(yp)
    return MAE

# %%
w = 3
b = 0.5
#np.linspace创建等差数列
x_lin = np.linspace(0, 100, 101)
#np.random.randn(101) * 5) * w + b 生随机数的函数
y = (x_lin + np.random.randn(101) * 5) * w + b
#plt.plot 畫圖 https://blog.csdn.net/chinwuforwork/article/details/51786967
#matplotlib.pyplot.plot(x,y,)参数详解
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 229.263
# The Mean absolute error is 11.917
